# %%
from scipy.stats import binom

# %%
binom.pmf(p=0.6,n=12,k=10)
# Out:
# np.float64(0.06385228185600002)

# %%
binom.pmf(p=0.5,n=5,k=2)
# Out:
# np.float64(0.31249999999999983)

# %%
binom.pmf(p=0.5,n=5,k=1)
# Out:
# np.float64(0.15624999999999997)

# %%
binom.pmf(p=0.5,n=5,k=0)
# Out:
# np.float64(0.031249999999999976)

# %%
binom.cdf(p=0.5,n=5,k=2)
# Out:
# np.float64(0.5)

# %%
import numpy as np
v=np.random.binomial(n=10,p=0.6,size=100)
v
# Out:
# array([6, 4, 6, 6, 3, 6, 7, 4, 6, 3, 7, 6, 7, 5, 8, 4, 8, 6, 4, 8, 8, 5,
#        7, 7, 7, 5, 7, 9, 8, 7, 9, 6, 5, 4, 4, 6, 8, 3, 6, 8, 6, 5, 8, 4,
#        8, 5, 6, 5, 7, 6, 6, 6, 7, 8, 6, 8, 5, 7, 7, 5, 6, 5, 8, 5, 6, 6,
#        7, 7, 4, 6, 7, 7, 6, 7, 3, 8, 2, 6, 6, 4, 7, 8, 5, 5, 4, 7, 4, 6,
#        5, 6, 6, 8, 7, 6, 7, 5, 5, 4, 5, 8], dtype=int32)

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sn

# %%
sn.histplot(v)
# Out:
# <Axes: ylabel='Count'>

# %%
from scipy.stats import poisson

# %%
poisson.pmf(k=5,mu = 3)
# Out:
# np.float64(0.10081881344492458)

# %%
v1=np.random.poisson(lam=3,size=1000)
v1
# Out:
# array([3, 4, 3, 2, 3, 2, 0, 0, 2, 5, 4, 4, 3, 4, 2, 2, 4, 5, 4, 3, 3, 4,
#        3, 1, 2, 4, 2, 4, 2, 3, 2, 1, 4, 1, 5, 2, 2, 3, 0, 5, 3, 1, 3, 3,
#        2, 1, 3, 2, 3, 1, 2, 1, 4, 5, 1, 1, 2, 1, 3, 4, 2, 6, 1, 1, 2, 1,
#        2, 4, 6, 5, 3, 5, 3, 2, 2, 3, 1, 3, 5, 2, 2, 2, 4, 4, 2, 0, 3, 0,
#        2, 2, 3, 6, 4, 3, 3, 5, 3, 4, 1, 1, 4, 3, 4, 6, 5, 4, 1, 4, 1, 3,
#        3, 1, 1, 3, 4, 2, 2, 0, 0, 1, 1, 1, 5, 3, 2, 2, 4, 0, 4, 1, 2, 2,
#        3, 5, 1, 1, 1, 5, 2, 0, 3, 4, 2, 2, 2, 3, 2, 5, 1, 0, 1, 3, 2, 4,
#        5, 1, 2, 2, 3, 3, 2, 1, 4, 3, 3, 3, 1, 8, 2, 0, 1, 3, 6, 0, 7, 4,
#        1, 5, 2, 2, 1, 0, 4, 3, 6, 1, 2, 6, 3, 3, 4, 2, 4, 3, 2, 0, 3, 1,
#        2, 4, 1, 1, 3, 2, 5, 3, 4, 2, 2, 2, 3, 2, 3, 5, 4, 6, 5, 1, 5, 4,
#        3, 3, 3, 4, 3, 3, 2, 2, 3, 4, 3, 6, 3, 4, 1, 2, 6, 4, 2, 3, 5, 3,
#        4, 2, 3, 4, 1, 1, 0, 5, 2, 4, 2, 7, 1, 3, 1, 0, 2, 3, 0, 2, 1, 2,
#        2, 1, 6, 5, 4, 3, 4, 5, 0, 3, 7, 7, 3, 2, 0, 3, 2, 5, 0, 3, 2, 1,
#        4, 1, 3, 3, 5, 3, 3, 2, 2, 6, 4, 2, 2, 3, 2, 4, 2, 4, 0, 1, 5, 4,
#        4, 4, 5, 0, 4, 3, 3, 3, 0, 7, 4, 1, 0, 1, 5, 0, 6, 1, 6, 2, 5, 1,
#        4, 0, 3, 3, 2, 3, 4, 8, 6, 0, 3, 6, 2, 2, 4, 3, 5, 3, 4, 8, 2, 6,
#        6, 6, 4, 2, 3, 1, 2, 4, 4, 0, 1, 3, 3, 0, 3, 3, 1, 3, 0, 2, 1, 1,
#        1, 1, 1, 4, 0, 1, 2, 0, 1, 8, 6, 3, 2, 6, 5, 3, 4, 3, 3, 0, 0, 4,
#        2, 4, 3, 4, 4, 4, 4, 2, 1, 2, 5, 0, 5, 2, 1, 4, 3, 6, 3, 2, 4, 2,
#        2, 2, 1, 3, 6, 2, 0, 4, 4, 2, 3, 2, 2, 7, 3, 5, 2, 8, 3, 1, 4, 3,
#        2, 2, 2, 1, 1, 6, 3, 1, 3, 0, 2, 3, 2, 0, 3, 3, 3, 3, 1, 3, 4, 1,
#        2, 4, 5, 2, 4, 4, 3, 5, 7, 4, 0, 2, 0, 3, 6, 5, 3, 2, 3, 1, 4, 2,
#        2, 3, 1, 2, 5, 2, 3, 1, 3, 4, 2, 3, 2, 2, 3, 2, 2, 5, 2, 2, 3, 1,
#        2, 3, 4, 3, 1, 5, 1, 3, 3, 4, 2, 2, 1, 5, 6, 3, 2, 4, 6, 4, 1, 1,
#        4, 5, 2, 4, 8, 1, 2, 1, 3, 1, 2, 2, 4, 4, 2, 3, 3, 3, 5, 3, 6, 3,
#        3, 2, 1, 5, 0, 3, 2, 4, 8, 1, 5, 1, 7, 3, 3, 3, 3, 3, 3, 4, 4, 3,
#        5, 2, 1, 2, 4, 1, 5, 5, 4, 3], dtype=int32)

# %%
sn.histplot(v1)
plt.show()
