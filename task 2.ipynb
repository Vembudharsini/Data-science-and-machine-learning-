# %%
#task 1
"""Task 1: Email Campaign Success 
Scenario:
A marketing team sends 50 promotional emails. Historically, 20% of users click the link.
Questions:
What is the probability that exactly 15 users click the email?
What is the probability that at least 10 users click?
What is the expected number of clicks?"""
from scipy.stats import binom
binom.pmf(p=0.2,n=50,k=15)
# Out:
# np.float64(0.029918656849901613)

# %%
from scipy.stats import binom
binom.sf(n=50,k=9,p=0.2)
# Out:
# np.float64(0.4164405815339337)

# %%
n = 50
p = 0.2
a = n * p
a
# Out:
# 10.0

# %%
#task 2 
"""Task 2: Quality Control in Manufacturing 
Scenario:
A factory produces microchips. Each chip has a 3% chance of being defective. A sample of 30 chips is tested.
Questions:
Probability that exactly 2 chips are defective?
Probability that no chips are defective?
Probability that more than 3 chips are defective?"""
from scipy.stats import binom
binom.pmf(k=2, n=30, p=0.03)
# Out:
# np.float64(0.16685542282351595)

# %%
from scipy.stats import binom
binom.pmf(k=0, n=30, p=0.03)
# Out:
# np.float64(0.40100706854315793)

# %%
binom.sf(k=3,n=30,p=0.03)
# Out:
# np.float64(0.011904642572061645)

# %%
#task 3
"""Placement Test Pass Rate 
Scenario:
In an online coding test, 60% of candidates pass. 20 students attempt the test.
Questions:
Probability that exactly 12 students pass?
Probability that fewer than 10 students pass?
How would the probability change if the difficulty increases and pass rate drops to 45%?"""

binom.pmf(k=12, n=20, p=0.6)
# Out:
# np.float64(0.17970578775468957)

# %%
binom.cdf(k=9, n=20, p=0.60)
# Out:
# np.float64(0.12752124614721674)

# %%
binom.pmf(k=12, n=20, p=0.45)
# Out:
# np.float64(0.07273087469288192)
