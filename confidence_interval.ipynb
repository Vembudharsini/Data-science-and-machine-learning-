# %%
import numpy as np
population=np.random.randint(1,100,size=100)
np.mean(population)
# Out:
# np.float64(49.99)

# %%
sample=np.array([15,  6, 49, 50, 45, 81,  9, 93, 50, 37, 96,  6, 21, 41, 45, 37, 51])
sample
# Out:
# array([15,  6, 49, 50, 45, 81,  9, 93, 50, 37, 96,  6, 21, 41, 45, 37, 51])

# %%
import scipy.stats as st
st.t.interval(confidence=0.95,df=len(sample)-1,loc=np.mean(sample),scale=st.sem(sample))
# Out:
# (np.float64(28.86310194434582), np.float64(57.254545114477715))
