# %%
#task 1 
"""Problem 1: Salary Analytics for HR Decision Making
Scenario:
A company’s HR team wants to analyze employee salaries to decide the average compensation for a new role. The salary data contains a few very highly paid executives.
Dataset:
employee_id, department, salary
Tasks:
Analyze the distribution of salary
Identify whether the data is skewed
Decide whether mean or median should be reported
Suggest data transformation (if needed)
Justify your approach using statistical reasoning"""
import pandas as pd
a = pd.read_csv("WA_Fn-UseC_-HR-Employee-Attrition.csv")
a
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
a.columns[a.isna().any()]
# Out:
# Index([], dtype='object')

# %%
from scipy.stats import skew

# %%
skew(a['MonthlyIncome'])
# Out:
# np.float64(1.3684185123330814)

# %%
import matplotlib.pyplot as plt
plt.hist(a['MonthlyIncome'])
plt.show()

# %%
import numpy as np
np.mean(a['MonthlyIncome'])
# Out:
# np.float64(6502.931292517007)

# %%
np.median(a['MonthlyIncome'])
# Out:
# np.float64(4919.0)

# %%
#task 2
"""Problem 2: House Price Prediction Model
Scenario:
You are building a linear regression model to predict house prices. Initial model results show high error and unstable coefficients.
Dataset:
area, bedrooms, bathrooms, price
Tasks:
Analyze skewness in the price feature
Verify normality using a Q–Q plot"""
import pandas as pd
h = pd.read_csv("House price.csv")
h
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
h.columns[h.isna().any()]
# Out:
# Index([], dtype='object')

# %%
from scipy.stats import skew

# %%
skew(h['price'])
# Out:
# np.float64(24.78284782965085)

# %%
import statsmodels.api as sm
sm.qqplot(h['price'],line='45')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.hist(h['price'])
plt.show()

# %%
#task 3
"""Problem 3: Credit Card Fraud Detection
Scenario:
A bank is monitoring transaction amounts to detect fraud. A few transactions are extremely high compared to the rest.
Dataset:
transaction_id, customer_id, amount
Tasks:
Apply Z-score to detect outliers
Identify limitations of Z-score in this scenario
Check the skewness of transaction amounts
Recommend a better outlier detection strategy"""
import pandas as pd 
import numpy as np  
import scipy.stats as stats
sa = pd.read_csv("transactions.csv")
sa
# Out:
#         step      type     amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0          8  CASH_OUT  158007.12   C424875646           0.00            0.00
# 1        236  CASH_OUT  457948.30  C1342616552           0.00            0.00
# 2         37   CASH_IN  153602.99   C900876541    11160428.67     11314031.67
# 3        331  CASH_OUT   49555.14   C177696810       10865.00            0.00
# 4        250  CASH_OUT   29648.02   C788941490           0.00            0.00
# ...      ...       ...        ...          ...            ...             ...
# 199994   201   PAYMENT    1274.97   C361372882       69376.00        68101.03
# 199995   212  CASH_OUT  204041.98  C1621547576       40423.00            0.00
# 199996   160   CASH_IN   66378.61  C1431532774     2852895.88      2919274.49
# 199997    12   CASH_IN   87473.93   C695681900     1674588.27      1762062.20
# 199998    15  CASH_OUT   97305.08   C809605956       21328.00            0.00
#
# ...

# %%
data.columns[data.isna().any()]
# Out:
# Index([], dtype='object')

# %%
import scipy.stats as s
stats.zscore(sa['amount'])
# Out:
# array([-0.0355455 ,  0.443941  , -0.04258595, ..., -0.18202299,
#        -0.14829998, -0.13258389], shape=(199999,))

# %%
from scipy.stats import skew
skew(sa['amount'])
# Out:
# np.float64(30.78782778743495)

# %%
import matplotlib.pyplot as plt
plt.hist(sa['amount'])
plt.show()
